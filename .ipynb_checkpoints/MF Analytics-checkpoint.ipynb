# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import seaborn as sns

# NLP
import nltk
from nltk.stem import WordNetLemmatizer 
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)

# %%
#combine all meatless farm data

# %%
mfbm = pd.read_csv('../Datasets/MFBurgerMeat.csv')
mfmm = pd.read_csv('../Datasets/MFMinceMeat.csv')[['reviewer_name', 'title', 'body', 'ratings']]
mfs = pd.read_csv('../Datasets/MFSausage.csv')[['reviewer_name', 'body', 'ratings']]
mfgm = pd.read_csv('../Datasets/MFGroundBasedMeat.csv')[['reviewer_name', 'title', 'body', 'ratings']]

# %%
mfbm.head()
# Out:
#                                                title  \
# 0       Not a Beef Replacment; Go for Something Else
# 1  Shocked my meat-eating friends with these deli...
# 2               Best meatless burgers on the market.
# 3                       Worst vegan burger available
# 4                                   Truly disgusting
#
#                                                 body   reviewer_name  ratings
# 0  Having looked to move away from meat for a whi...          Rhodri        2
# 1  \n  Absolutely brilliant. I jumped on to leave...           Suzie        5
# 2  \n  Hubby and I were not sure whether to try m...  Veronica Clark        5
# 3  \n  How could anyone eat these? They taste of ...           Marge        1
# 4  \n  Honestly never tried anything quite as rev...              RC        1

# %%
mfmm.head()
# Out:
#    reviewer_name                       title  \
# 0          Chloe              Mixed emotions
# 1        Martina  Delicious meatless mince!!
# 2        Rogerio      Worst meat alternative
# 3          Chris               Smells so bad
# 4  Carol Edwards           Best of the bunch
#
#                                                 body  ratings
# 0  \n I have tried many different meat/mince alte...        3
# 1  \n I am Italian and as a good Italian I love l...        5
# 2  \n This must be the worst meat alternative eve...        1
# 3  \n Absolutely vile smell when cooking, really ...        1
# 4  \n This is the first time I have used this min...        5

# %%
#include each category

mfbm['category'] = 'burger_meat'
mfmm['category'] = 'mince_meat'
mfs['category'] = 'sausage'
mfgm['category'] = 'ground_meat'

# %%
mfbm.head()
# Out:
#                                                title  \
# 0       Not a Beef Replacment; Go for Something Else
# 1  Shocked my meat-eating friends with these deli...
# 2               Best meatless burgers on the market.
# 3                       Worst vegan burger available
# 4                                   Truly disgusting
#
#                                                 body   reviewer_name  ratings  \
# 0  Having looked to move away from meat for a whi...          Rhodri        2
# 1  \n  Absolutely brilliant. I jumped on to leave...           Suzie        5
# 2  \n  Hubby and I were not sure whether to try m...  Veronica Clark        5
# 3  \n  How could anyone eat these? They taste of ...           Marge        1
# 4  \n  Honestly never tried anything quite as rev...              RC        1
#
#       category
# 0  burger_meat
# 1  burger_meat
# 2  burger_meat
# 3  burger_meat
# 4  burger_meat

# %%
mfgm.head(2)
# Out:
#                reviewer_name                   title  \
# 0  Dream 4 More Book Reviews  try over another brand
# 1                        B W     Bland, Poor Texture
#
#                                                 body  ratings     category
# 0  \n I do not like Beyond Crumbles, the taste bu...        3  ground_meat
# 1  \n This isn't even in the same playing field a...        1  ground_meat

# %%
# combine title and body

mfbm['review'] = mfbm['title'] + ' ' + mfbm['body'] 
mfmm['review'] = mfmm['title'] + ' ' + mfmm['body'] 
mfs['review'] = mfs['body']
mfgm['review'] = mfgm['title'] + ' ' + mfgm['body']

# %%
#drop unwanted columns

mfbm.drop(columns = ['title', 'body'], inplace=True)
mfmm.drop(columns = ['title', 'body'], inplace=True)
mfs.drop(columns = ['body'], inplace=True)
mfgm.drop(columns = ['title', 'body'], inplace=True)

# %%
mfbm.head(2)
# Out:
#   reviewer_name  ratings     category  \
# 0        Rhodri        2  burger_meat
# 1         Suzie        5  burger_meat
#
#                                               review
# 0  Not a Beef Replacment; Go for Something Else H...
# 1  Shocked my meat-eating friends with these deli...

# %%
mfmm.head(2)
# Out:
#   reviewer_name  ratings    category  \
# 0         Chloe        3  mince_meat
# 1       Martina        5  mince_meat
#
#                                               review
# 0  Mixed emotions \n I have tried many different ...
# 1  Delicious meatless mince!! \n I am Italian and...

# %%
mfs.head(2)
# Out:
#   reviewer_name  ratings category  \
# 0         sarah        3  sausage
# 1         laura        5  sausage
#
#                                               review
# 0  Not Bad; These sausages aren't so bad if you s...
# 1  Meat free Sausages; They were OK nothing speci...

# %%
mfgm.head(2)
# Out:
#                reviewer_name  ratings     category  \
# 0  Dream 4 More Book Reviews        3  ground_meat
# 1                        B W        1  ground_meat
#
#                                               review
# 0  try over another brand \n I do not like Beyond...
# 1  Bland, Poor Texture \n This isn't even in the ...

# %%
# define a function to clean

def clean_text(text):
    
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub('[''""...]', '', text)
    text = re.sub('\n', '', text)
    text = re.sub("[^a-zA-Z0-9]+", " ",text)
    text = text.replace('[removed]', '')
    text = text.replace('[deleted]', '')
    text = text.replace('?', '')
    text = text.replace('!', '')
    text = text.replace('()', '')
    text = text.replace(',', '')
    text = text.replace("'", '')
    text = text.replace("http", '')
    
    return text

# %%
def lower_case(text):
    
    text = text.lower()
    return text

# %%
# lowercase all reviewer names

mfbm['reviewer_name'] = mfbm['reviewer_name'].apply(lower_case)
mfmm['reviewer_name'] = mfmm['reviewer_name'].apply(lower_case)
mfs['reviewer_name'] = mfs['reviewer_name'].apply(lower_case)
mfgm['reviewer_name'] = mfgm['reviewer_name'].apply(lower_case)

# %%
# clean the reviews

mfbm['review'] = mfbm['review'].apply(clean_text)
mfmm['review'] = mfmm['review'].apply(clean_text)
mfs['review'] = mfs['review'].apply(clean_text)
mfgm['review'] = mfgm['review'].apply(clean_text)

# %%
#check

mfbm.head()
# Out:
#     reviewer_name  ratings     category  \
# 0          rhodri        2  burger_meat
# 1           suzie        5  burger_meat
# 2  veronica clark        5  burger_meat
# 3           marge        1  burger_meat
# 4              rc        1  burger_meat
#
#                                               review
# 0  not a beef replacment go for something else ha...
# 1  shocked my meat eating friends with these deli...
# 2  best meatless burgers on the market hubby and ...
# 3  worst vegan burger available how could anyone ...
# 4  truly disgusting honestly never tried anything...

# %%
mfmm.head(3)
# Out:
#   reviewer_name  ratings    category  \
# 0         chloe        3  mince_meat
# 1       martina        5  mince_meat
# 2       rogerio        1  mince_meat
#
#                                               review
# 0  mixed emotions n i have tried many different m...
# 1  delicious meatless mince n i am italian and as...
# 2  worst meat alternative n this must be the wors...

# %%
mfs.head(2)
# Out:
#   reviewer_name  ratings category  \
# 0         sarah        3  sausage
# 1         laura        5  sausage
#
#                                               review
# 0  not bad these sausages aren t so bad if you se...
# 1  meat free sausages they were ok nothing specia...

# %%
mfgm.head(2)
# Out:
#                reviewer_name  ratings     category  \
# 0  dream 4 more book reviews        3  ground_meat
# 1                        b w        1  ground_meat
#
#                                               review
# 0  try over another brand n i do not like beyond ...
# 1  bland poor texture n this isn t even in the sa...

# %%
MFcombine = pd.concat([mfbm, mfmm, mfs, mfgm])

# %%
MFcombine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 42
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reviewer_name  205 non-null    object
#  1   ratings        205 non-null    int64
#  2   category       205 non-null    object
#  3   review         205 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 8.0+ KB

# %%
MFcombine
# Out:
#                  reviewer_name  ratings     category  \
# 0                       rhodri        2  burger_meat
# 1                        suzie        5  burger_meat
# 2               veronica clark        5  burger_meat
# 3                        marge        1  burger_meat
# 4                           rc        1  burger_meat
# 5               jason thompson        1  burger_meat
# 6                   sara villa        1  burger_meat
# 7                        amy m        1  burger_meat
# 8              daniela craciun        5  burger_meat
# 9                        esf22        5  burger_meat
# 10                      cheryl        5  burger_meat
# 11                          jo        1  burger_meat
# 12               gareth larkin        1  burger_meat
# 13                      simone        5  burger_meat
# 14               mark jacobson        1  burger_meat
# 15             mikkeline hicks        5  burger_meat
# 16                     joshi a        1  burger_meat
# 17                        amy         4  burger_meat
# 18                   barbara f        2  burger_meat
# 19                        eric        5  burger_meat
# 20                      ashley        1  burger_meat
# 21                misty wilder        1  burger_meat
# 22                      althea        5  burger_meat
# 23                      mickey        5  burger_meat
# 24                   john hein        5  burger_meat
# 25                emmalaurence        1  burger_meat
# 26                           c        5  burger_meat
# 27                       cjohn        2  burger_meat
# 28                         tom        1  burger_meat
# 29           aprendiz de brujo        5  burger_meat
# 30                ned j. soltz        2  burger_meat
# 31           dothline campbell        1  burger_meat
# 32             amazon customer        1  burger_meat
# 33                       gabby        5  burger_meat
# 34              steven roberts        1  burger_meat
# 35                   oliveista        4  burger_meat
# 36                 nicole west        5  burger_meat
# 37              trudy a ehrsam        5  burger_meat
# 38                       april        3  burger_meat
# 39                   eco smile        5  burger_meat
# 40                          lb        3  burger_meat
# 41             amazon customer        2  burger_meat
# 42                      ildika        3  burger_meat
# 43                         jlj        5  burger_meat
# 44   \teli salas 3 of wellford        3  burger_meat
# 45                rich galindo        1  burger_meat
# 46              michael ashton        5  burger_meat
# 47                      zchery        1  burger_meat
# 0                        chloe        3   mince_meat
# 1                      martina        5   mince_meat
# 2                      rogerio        1   mince_meat
# 3                        chris        1   mince_meat
# 4                carol edwards        5   mince_meat
# 5                   julzrichie        5   mince_meat
# 6              amazon customer        5   mince_meat
# 7                natalie north        5   mince_meat
# 8               rosaline leach        5   mince_meat
# 9            alexander orchard        2   mince_meat
# 10                       kat j        1   mince_meat
# 11                  mr. p. w.         5   mince_meat
# 0                        sarah        3      sausage
# 1                        laura        5      sausage
# 2                       stella        4      sausage
# 3                       lauren        5      sausage
# 4                            k        5      sausage
# 21   thumbs down n disgusting product need to revis...
# 22   good alternative n good alternative for the fi...
# 23   needs to cook much longer than other meatless ...
# 24                                     gross n gross n
# 25   best plant based meat alternative n this is th...
# 26     not good n just not good bad unnatural flavor n
# 27   great n great alternative to the strong flavor...
# 28   good stuff my dude n great substitute made mea...
# 29   like the playdough that comes out of the spagh...
# 30   definitely a keeper n tried and love the meatl...
# 31   not as good as other brands n the meatless far...
# 32   delicious n made lasagna with this tonight it ...
# 33   yummy when cooked properly n delicious great t...
# 34   edible n strong tvp flavor the appearance is w...
# 35   terrible n i ve been a vegetarian for years an...
# 36   tastes awful loaded with crap n horrible beyon...
# 37   not a good meat substitute option n yuck taste...
# 38   great n i used this to make vegan sloppy joes ...
# 39   yikes not as good as the new comers beyond and...
# 40   gross won t buy again expected something like ...
# 41   terrible not even remotely as good as the comp...
# 42   vegan and tolerable this product does not have...

# %%
MFcombine['ratings'].value_counts()
# Out:
# 5    85
# 1    45
# 4    38
# 3    19
# 2    18
# Name: ratings, dtype: int64

# %%
plt.title('MF rating counts')
sns.countplot(MFcombine.ratings)

# %%
# MFcombine.groupby('category')['ratings'].value_counts()

# %%
# tokenisation

tokenizer = RegexpTokenizer(r'\w+', gaps=False)

# %%
MFcombine['review_token'] = MFcombine['review'].apply(tokenizer.tokenize)

# %%
MFcombine.head()
# Out:
#     reviewer_name  ratings     category  \
# 0          rhodri        2  burger_meat
# 1           suzie        5  burger_meat
# 2  veronica clark        5  burger_meat
# 3           marge        1  burger_meat
# 4              rc        1  burger_meat
#
#                                               review  \
# 0  not a beef replacment go for something else ha...
# 1  shocked my meat eating friends with these deli...
# 2  best meatless burgers on the market hubby and ...
# 3  worst vegan burger available how could anyone ...
# 4  truly disgusting honestly never tried anything...
#
#                                         review_token
# 0  [not, a, beef, replacment, go, for, something,...
# 1  [shocked, my, meat, eating, friends, with, the...
# 2  [best, meatless, burgers, on, the, market, hub...
# 3  [worst, vegan, burger, available, how, could, ...
# 4  [truly, disgusting, honestly, never, tried, an...

# %%
# stop words

stopwords_basic = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'browser', 'support', 'video']

# %%
MFcombine['review_token_stop'] = MFcombine['review_token'].apply(lambda x: [item for item in x if item not in stopwords_basic])

# %%
MFcombine.head()
# Out:
#     reviewer_name  ratings     category  \
# 0          rhodri        2  burger_meat
# 1           suzie        5  burger_meat
# 2  veronica clark        5  burger_meat
# 3           marge        1  burger_meat
# 4              rc        1  burger_meat
#
#                                               review  \
# 0  not a beef replacment go for something else ha...
# 1  shocked my meat eating friends with these deli...
# 2  best meatless burgers on the market hubby and ...
# 3  worst vegan burger available how could anyone ...
# 4  truly disgusting honestly never tried anything...
#
#                                         review_token  \
# 0  [not, a, beef, replacment, go, for, something,...
# 1  [shocked, my, meat, eating, friends, with, the...
# 2  [best, meatless, burgers, on, the, market, hub...
# 3  [worst, vegan, burger, available, how, could, ...
# 4  [truly, disgusting, honestly, never, tried, an...
#
#                                    review_token_stop
# 0  [beef, replacment, go, something, else, looked...
# 1  [shocked, meat, eating, friends, delicious, th...
# 2  [best, meatless, burgers, market, hubby, sure,...
# 3  [worst, vegan, burger, available, could, anyon...
# 4  [truly, disgusting, honestly, never, tried, an...

# %%
# test = " ".join(review for review in MFcombine['review'])

# %%
# try to lemmatise

def lem(x):
#-----------------------------------
# Input:
# x - post text
# Output:
# string of lemmatized words
#-----------------------------------
    lemmatizer = WordNetLemmatizer()
    
    #lemmatize words
    lemm_words = [lemmatizer.lemmatize(word.lower()) for word in x]
    
    #return lemmatized and stem words in a string
    return ' '.join(lemm_words)

# %%
MFcombine['review_token_stop_lem'] = MFcombine['review_token_stop'].apply(lem)

# %%
MFcombine.head()
# Out:
#     reviewer_name  ratings     category  \
# 0          rhodri        2  burger_meat
# 1           suzie        5  burger_meat
# 2  veronica clark        5  burger_meat
# 3           marge        1  burger_meat
# 4              rc        1  burger_meat
#
#                                               review  \
# 0  not a beef replacment go for something else ha...
# 1  shocked my meat eating friends with these deli...
# 2  best meatless burgers on the market hubby and ...
# 3  worst vegan burger available how could anyone ...
# 4  truly disgusting honestly never tried anything...
#
#                                         review_token  \
# 0  [not, a, beef, replacment, go, for, something,...
# 1  [shocked, my, meat, eating, friends, with, the...
# 2  [best, meatless, burgers, on, the, market, hub...
# 3  [worst, vegan, burger, available, how, could, ...
# 4  [truly, disgusting, honestly, never, tried, an...
#
#                                    review_token_stop  \
# 0  [beef, replacment, go, something, else, looked...
# 1  [shocked, meat, eating, friends, delicious, th...
# 2  [best, meatless, burgers, market, hubby, sure,...
# 3  [worst, vegan, burger, available, could, anyon...
# 4  [truly, disgusting, honestly, never, tried, an...
#
#                                review_token_stop_lem
# 0  beef replacment go something else looked move ...
# 1  shocked meat eating friend delicious thing abs...
# 2  best meatless burger market hubby sure whether...
# 3  worst vegan burger available could anyone eat ...
# 4  truly disgusting honestly never tried anything...

# %%
MFcombine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 42
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   reviewer_name          205 non-null    object
#  1   ratings                205 non-null    int64
#  2   category               205 non-null    object
#  3   review                 205 non-null    object
#  4   review_token           205 non-null    object
#  5   review_token_stop      205 non-null    object
#  6   review_token_stop_lem  205 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 17.8+ KB

# %%
# get top words WITHOUT stop words / lemmatize

# %%
high_rating = MFcombine[MFcombine['ratings'] >= 4]

# %%
low_rating = MFcombine[MFcombine['ratings'] <= 2]

# %%
#without stop words / lemmatising / stemming

TfidfVectorizer

tf = TfidfVectorizer()
tf.fit(low_rating['review'])

len_features = len(tf.get_feature_names())
print(len_features)

MFcombine_cv_tf = pd.DataFrame(tf.transform(low_rating['review']).todense(),columns=tf.get_feature_names())

print('Low rating important one-word')
top_MFCombine_tf = MFcombine_cv_tf.sum(axis=0)
top_MFCombine_tf.sort_values(ascending = False).head(20)
# Out:
# 734
# Low rating important one-word
# and       4.607423
# not       4.423589
# the       4.219301
# it        4.054325
# to        3.511629
# as        3.444354
# taste     3.330714
# like      3.219540
# meat      2.653210
# of        2.588833
# for       2.562220
# burger    2.544091
# beyond    2.463934
# these     2.456556
# good      2.418387
# this      2.357867
# they      2.155734
# but       2.142421
# is        2.070622
# tastes    1.798018
# dtype: float64

# %%
#bi-gram

TfidfVectorizer

tf = TfidfVectorizer(ngram_range = (2,2))
tf.fit(low_rating['review'])

len_features = len(tf.get_feature_names())
print(len_features)

MFcombine_cv_tf = pd.DataFrame(tf.transform(low_rating['review']).todense(),columns=tf.get_feature_names())

top_MFCombine_tf = MFcombine_cv_tf.sum(axis=0)
top_MFCombine_tf.sort_values(ascending = False).head(20)
# Out:
# 1989
# not good            1.596823
# beyond burger       1.250672
# gross gross         1.000000
# yuck taste          0.820981
# tastes like         0.801097
# taste like          0.757706
# cat food            0.713995
# dog food            0.709531
# buy again           0.697305
# much better         0.693312
# at all              0.679854
# this product        0.673796
# do not              0.663100
# not as              0.649804
# meat alternative    0.632264
# it has              0.620267
# like dog            0.619150
# meat free           0.612547
# as good             0.599125
# good as             0.599125
# dtype: float64

# %%
# tri-gram

TfidfVectorizer

tf = TfidfVectorizer(ngram_range = (3,3))
tf.fit(low_rating['review'])

len_features = len(tf.get_feature_names())
print(len_features)

MFcombine_cv_tf = pd.DataFrame(tf.transform(low_rating['review']).todense(),columns=tf.get_feature_names())

top_MFCombine_tf = MFcombine_cv_tf.sum(axis=0)
top_MFCombine_tf.sort_values(ascending = False).head(20)
# Out:
# 2214
# as good as                0.596213
# not for me                0.547381
# yuck taste like           0.500000
# dog food smells           0.500000
# taste like dog            0.500000
# like dog food             0.500000
# good as the               0.488418
# as tasty as               0.485665
# tasty as beyond           0.485665
# as beyond burger          0.485665
# smell when cooking        0.444894
# amp didn cook             0.408248
# blaghh bland dry          0.408248
# just not good             0.408248
# bad unnatural flavor      0.408248
# substitute option yuck    0.408248
# not good just             0.408248
# not good meat             0.408248
# good bad unnatural        0.408248
# not good bad              0.408248
# dtype: float64

# %%
# WITH stopwords and lemmatizing

# %%
#TfidfVectorizer

tf = TfidfVectorizer()
tf.fit(low_rating['review_token_stop_lem'])

len_features = len(tf.get_feature_names())
print(len_features)

MFcombine_cv_tf = pd.DataFrame(tf.transform(low_rating['review_token_stop_lem']).todense(),columns=tf.get_feature_names())

top_MFCombine_tf = MFcombine_cv_tf.sum(axis=0)
top_MFCombine_tf.sort_values(ascending = False).head(20)
# Out:
# 601
# taste      4.846124
# burger     3.905043
# like       3.866870
# meat       3.247726
# beyond     2.978500
# good       2.844709
# smell      2.366274
# texture    2.154077
# tried      2.127186
# dry        2.104891
# food       2.055599
# awful      1.915918
# vegan      1.904046
# would      1.885418
# buy        1.875747
# product    1.846258
# really     1.770404
# even       1.733514
# flavor     1.678427
# better     1.618280
# dtype: float64

# %%
#bi-gram

TfidfVectorizer

tf = TfidfVectorizer(ngram_range = (2,2))
tf.fit(low_rating['review_token_stop_lem'])

len_features = len(tf.get_feature_names())
print(len_features)

MFcombine_cv_tf = pd.DataFrame(tf.transform(low_rating['review_token_stop_lem']).todense(),columns=tf.get_feature_names())

top_MFCombine_tf = MFcombine_cv_tf.sum(axis=0)
top_MFCombine_tf.sort_values(ascending = False).head(20)
# Out:
# 1181
# beyond burger        1.675238
# taste like           1.567360
# gross gross          1.000000
# cat food             0.899150
# yuck taste           0.850282
# meat free            0.838033
# meat alternative     0.836633
# taste much           0.832411
# vegan burger         0.823625
# much better          0.812335
# dog food             0.794438
# like dog             0.665934
# burger available     0.660913
# worst meat           0.640349
# worst vegan          0.636265
# beyond impossible    0.627514
# beyond meat          0.599772
# like meat            0.595799
# tasty beyond         0.593910
# waste money          0.573248
# dtype: float64

# %%
#tri-gram

TfidfVectorizer

tf = TfidfVectorizer(ngram_range = (3,3))
tf.fit(low_rating['review_token_stop_lem'])

len_features = len(tf.get_feature_names())
print(len_features)

MFcombine_cv_tf = pd.DataFrame(tf.transform(low_rating['review_token_stop_lem']).todense(),columns=tf.get_feature_names())

top_MFCombine_tf = MFcombine_cv_tf.sum(axis=0)
top_MFCombine_tf.sort_values(ascending = False).head(20)
# Out:
# 1219
# taste much better           0.734881
# vegan burger available      0.681140
# tasty beyond burger         0.626907
# snuff average taste         0.577350
# good good bad               0.577350
# average taste bother        0.577350
# good bad unnatural          0.577350
# dry snuff average           0.577350
# bad unnatural flavor        0.577350
# worst vegan burger          0.557196
# spaghetti fitting yuck      0.500000
# yuck taste like             0.500000
# like dog food               0.500000
# dog food smell              0.500000
# come spaghetti fitting      0.500000
# like playdough come         0.500000
# taste like dog              0.500000
# playdough come spaghetti    0.500000
# cook like meat              0.447214
# good meat substitute        0.447214
# dtype: float64

# %%
# high rating

TfidfVectorizer

tf = TfidfVectorizer(ngram_range = (2,2))
tf.fit(high_rating['review'])

len_features = len(tf.get_feature_names())
print(len_features)

MFcombine_cv_tf = pd.DataFrame(tf.transform(high_rating['review']).todense(),columns=tf.get_feature_names())

top_MFCombine_tf = MFcombine_cv_tf.sum(axis=0)
top_MFCombine_tf.sort_values(ascending = False).head(20)
# Out:
# 3055
# they are            2.148557
# meat free           1.684549
# plant based         1.673058
# really tasty        1.553553
# taste like          1.467691
# the taste           1.344508
# these are           1.334870
# this is             1.267728
# tasty and           1.239383
# better than         1.193299
# the texture         1.190192
# they were           1.169333
# good alternative    1.131599
# like meat           1.130718
# the best            1.099033
# really good         1.078536
# very good           1.068794
# alternative to      1.063630
# and texture         1.049587
# these sausages      1.047770
# dtype: float64

# %%
#uni-gram

TfidfVectorizer

tf = TfidfVectorizer()
tf.fit(high_rating['review_token_stop_lem'])

len_features = len(tf.get_feature_names())
print(len_features)

MFcombine_cv_tf = pd.DataFrame(tf.transform(high_rating['review_token_stop_lem']).todense(),columns=tf.get_feature_names())

top_MFCombine_tf = MFcombine_cv_tf.sum(axis=0)
top_MFCombine_tf.sort_values(ascending = False).head(20)
# Out:
# 712
# good           8.898934
# meat           8.513124
# sausage        7.656642
# great          7.180121
# taste          6.498201
# like           5.107623
# really         4.955256
# texture        4.920406
# alternative    4.809539
# love           4.700410
# tasty          4.571757
# vegan          4.288988
# burger         3.640759
# product        3.416320
# meatless       3.356517
# delicious      3.273010
# free           3.233148
# best           2.973688
# flavour        2.893213
# tried          2.832703
# dtype: float64

# %%
#bi-gram

TfidfVectorizer

tf = TfidfVectorizer(ngram_range = (2,2))
tf.fit(high_rating['review_token_stop_lem'])

len_features = len(tf.get_feature_names())
print(len_features)

MFcombine_cv_tf = pd.DataFrame(tf.transform(high_rating['review_token_stop_lem']).todense(),columns=tf.get_feature_names())

top_MFCombine_tf = MFcombine_cv_tf.sum(axis=0)
top_MFCombine_tf.sort_values(ascending = False).head(20)
# Out:
# 1893
# plant based             2.111303
# meat free               2.090203
# taste like              1.981176
# really tasty            1.939036
# good alternative        1.494902
# really good             1.353581
# like meat               1.328219
# great alternative       1.209220
# beyond burger           1.193050
# like real               1.130857
# meat alternative        1.125123
# meat substitute         1.112609
# taste texture           1.106828
# meat sausage            1.102341
# meatless burger         1.092693
# great taste             1.065118
# veggie sausage          1.022712
# taste good              1.012771
# great meat              1.011843
# definitely recommend    1.008312
# dtype: float64

# %%
text_high = " ".join(review for review in high_rating['review_token_stop_lem'])

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

wordcloud_high = WordCloud(background_color="white").generate(text_high)

# %%
wordcloud_high

# %%
plt.imshow(wordcloud_high, interpolation='bilinear')
plt.axis("off")
plt.title('High ratings\n')
plt.show()

# %%
text_low = " ".join(review for review in low_rating['review_token_stop_lem'])

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

wordcloud_low = WordCloud(background_color="white").generate(text_low)

# %%
plt.imshow(wordcloud_low, interpolation='bilinear')
plt.axis("off")
plt.title('Low ratings\n')
plt.show()

# %%
#without stop words

# %%
text_low_alt = " ".join(review for review in low_rating['review'])

# %%
wordcloud_low_alt = WordCloud(background_color="white").generate(text_low_alt)

# %%
plt.imshow(wordcloud_low_alt, interpolation='bilinear')
plt.axis("off")
plt.title('Low ratings\n')
plt.show()

# %%
# save the combined MF file

# %%
# MFcombine.to_csv('MFCombine.csv')
